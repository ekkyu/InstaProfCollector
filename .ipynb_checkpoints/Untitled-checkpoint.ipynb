# %%
# -*- coding: utf-8 -*-

import json
import re
import csv
import os
import requests
from typing import Dict
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pprint

f = open("config.json")
config = json.load(f)

f2= open("user_id.json")
list_user_name = json.load(f2)

proxies = {
    "http": config["proxy"],
    "https": config["proxy"],
    }

class PlofileCollecter:
    
    def __init__(self):
        self.proxies = proxies
        self.file_pass = "img/{}.png"
        self.plofile_data = {}
        self.instagram_plofile_url = "https://www.instagram.com/{}/"
        self.label = ["id", "url", "icon", "biography", "country", "post_num", "follow", "follower", "hashtag_12post"]
        self.post_num_hashtag = 12

    def download_img(self, url, user_name):
        r = requests.get(url, stream=True)
        if r.status_code == 200:
            save_file_name = self.file_pass.format(user_name)
            with open(save_file_name, 'wb') as f:
                f.write(r.content)

    def get_jsondata_from_username(self, user_name_i):
        url = self.instagram_plofile_url.format(user_name_i)
        self.plofile_data['url'] = url
        response = requests.get(url, proxies=proxies, verify=False)

        soup = BeautifulSoup(response.content, 'html.parser') # 'lxml'  -> 'html.parser' 
        js = soup.find("script", text=re.compile("window._sharedData")).text
        json_data = json.loads(js[js.find("{"):js.rfind("}")+1]);
        pprint.pprint(json_data)
        return json_data
    
    def get_plofile_data_from_jsondata(self, json_data):
        user_data = json_data['entry_data']['ProfilePage'][0]['graphql']['user']
        timeline_media = user_data['edge_owner_to_timeline_media'][ 'edges']
        self.plofile_data['icon_src'] = user_data['profile_pic_url']
        self.plofile_data['biography'] = user_data['biography']        
        self.plofile_data['country'] = json_data['country_code']
        self.plofile_data['post'] = user_data['edge_owner_to_timeline_media']['count']
        self.plofile_data['follow'] = user_data['edge_follow']['count']
        self.plofile_data['follower'] = user_data['edge_followed_by']['count']
        
        hashtag = []
        for i in range(min(self.post_num_hashtag, int(self.plofile_data['post']))):
            try:
                text = timeline_media[i]['node']['edge_media_to_caption']['edges'][0]['node']['text']
                hashtag.append(self.text2hashtag(text))
            except:
                pass
        self.plofile_data['hashtag'] = self.flatten(hashtag)
        
    def text2hashtag(self, text):
        pattern = "\#[^(\ ¥\#¥\n)]*"
        return re.findall(pattern, text)
    
    def flatten(self, nested_list):
        """2重のリストをフラットにする関数"""
        return [e for inner_list in nested_list for e in inner_list]
        
    def save_idlist2json_file(self, data):
        file_name = "data.json"
        fw = open(file_name,'w')
        json.dump(data, fw, indent=4)
        
    def write2csv(self, row_data):
        if os.path.exists('data.csv'):
            with open('data.csv', 'a') as f_csv:
                writer = csv.writer(f_csv)
                writer.writerow(row_data)
        else:
            with open('data.csv', 'w') as f_csv:
                writer = csv.writer(f_csv)
                writer.writerow(self.label)
                writer.writerow(row_data)

    def main_loop(self, list_user_name):
        for user_num_i, user_name_i in enumerate(list_user_name):
            try:
                self.plofile_data['username'] = user_name_i
                json_data = self.get_jsondata_from_username(user_name_i)
                self.get_plofile_data_from_jsondata(json_data)
                self.download_img(self.plofile_data['icon_src'], user_name_i)   
                print("---------{}/{}---------".format(user_num_i + 1, len(list_user_name)))
                #print(self.plofile_data.values())
                self.write2csv(self.plofile_data.values())
            except:
                pass
            
if __name__ == '__main__':
    pass
    #pc = PlofileCollecter()
    #pc.main_loop(list_user_name)

# %%
pc = PlofileCollecter()            
pc.get_jsondata_from_username("ekkkkyu")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'bundle_variant': 'metro',
#  'cache_schema_version': 3,
#  'config': {'csrf_token': 'tbvjB0OMk2xhLw4cas5qTPLbIOszId6S',
#             'viewer': None,
#             'viewerId': None},
#  'country_code': 'JP',
#  'deployment_stage': 'c2',
#  'entry_data': {'ProfilePage': [{'graphql': {'user': {'biography': '5パーセントの確率でインスタ映えする写真をアップします',
#                                                       'blocked_by_viewer': False,
#                                                       'business_category_name': 'Creators '
#                                                                                 '& '
#                                                                                 'Celebrities',
#                                                       'connected_fb_page': None,
#                                                       'country_block': False,
#                                                       'edge_felix_video_timeline': {'count': 0,
#                                                                                     'edges': [],
#                                                                                     'page_info': {'end_cursor': None,
#                                                                                                   'has_next_page': False}},
#                                                       'edge_follow': {'count': 838},
#                                                       'edge_followed_by': {'count': 581},
#                                                       'edge_media_collections': {'count': 0,
#                                                                                  'edges': [],
#                                                                                  'page_info': {'end_cursor': None,
#                                                                                                'has_next_page': False}},
#                                                       'edge_mutual_followed_by': {'count': 0,
#                                                                                   'edges': []},
#                                                       'edge_owner_to_timeline_media': {'count': 85,
#                                                                                        'edges': [{'node': {'__typename': 'GraphSidecar',
#                                                                                                            'accessibility_caption': 'Image '
#                                                                                                                                     'may '
#                                                                                                                                     'contain: '
#                                                                                                                                     'shoes',
#                                                                                                            'comments_disabled': False,
#                                                                                                            'dimensions': {'height': 1080,
#                                                                                                                           'width': 1080},
#                                                                                                            'display_url': 'https://scontent-nrt1-1.cdninstagram.com/vp/ea9f18bb95ee8138a340fa430e230631/5DC3FB3E/t51.2885-15/e35/58408887_356170725017607_2663512426923857684_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com',
#                                                                                                            'edge_liked_by': {'count': 336},
#                                                                                                            'edge_media_preview_like': {'count': 336},
#                                                                                                            'edge_media_to_caption': {'edges': [{'node': {'text': '履くのが楽しみ\n'
#                                                                                                                                                                  '#teva '
#                                                                                                                                                                  '#mhl '
#                                                                                                                                                                  '#margarethowell'}}]},
#                                                                                                            'edge_media_to_comment': {'count': 2},
#                                                                                                            'gating_info': None,
#                                                                                                            'id': '2035458382072618013',
#                                                                                                            'is_video': False,
#                                                                                                            'location': None,
#                                                                                                            'media_preview': None,
#                                                                                                            'owner': {'id': '1472461946',
#                                                                                                                      'username': 'ekkkkyu'},
#                                                                                                            'shortcode': 'Bw_Zp06h5wd',
#                                                                                                            'taken_at_timestamp': 1556865569,
#                                                                                                            'thumbnail_resources': [{'config_height': 150,
#                                                                                                                                     'config_width': 150,
#                                                                                                                                     'src': 'https://scontent-nrt1-1.cdninstagram.com/vp/1c7d830cd6c15040cc361177054bc01e/5DA5EB7C/t51.2885-15/e35/s150x150/58408887_356170725017607_2663512426923857684_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com'},
#                                                                                                                                    {'config_height': 240,
#                                                                                                                                     'config_width': 240,
#                                                                                                                                     'src': 'https://scontent-nrt1-1.cdninstagram.com/vp
n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com',
#             'config_width': 480,
#             'config_height': 480},
#            {'src': 'https://scontent-nrt1-1.cdninstagram.com/vp/7dac9111d60b254cacd366c8ed90dada/5DC0952D/t51.2885-15/sh0.08/e35/s640x640/44193987_2390915080924100_7806356105071346470_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com',
#             'config_width': 640,
#             'config_height': 640}],
#           'is_video': False,
#           'accessibility_caption': 'No photo description available.'}}]},
#       'edge_saved_media': {'count': 0,
#        'page_info': {'has_next_page': False, 'end_cursor': None},
#        'edges': []},
#       'edge_media_collections': {'count': 0,
#        'page_info': {'has_next_page': False, 'end_cursor': None},
#        'edges': []}}},
#     'show_follow_dialog': False,
#     'toast_content_on_load': None}]},
#  'hostname': 'www.instagram.com',
#  'deployment_stage': 'c2',
#  'platform': 'web',
#  'nonce': 'uucKLWKs5ny2oPs48ZEddg==',
#  'mid_pct': 83.63033,
#  'zero_data': {},
#  'cache_schema_version': 3,
#  'server_checks': {},
#  'knobs': {'acct:ntb': 0, 'cb': 0, 'captcha': 0, 'fr': 0},
#  'to_cache': {'gatekeepers': {'4': True,
#    '5': False,
#    '6': False,
#    '7': False,
#    '8': False,
#    '9': False,
#    '10': False,
#    '11': False,
#    '12': False,
#    '13': True,
#    '14': True,
#    '15': True,
#    '16': True,
#    '18': True,
#    '19': False,
#    '23': False,
#    '24': False,
#    '26': True,
#    '27': False,
#    '28': False,
#    '29': True,
#    '31': False,
#    '32': True,
#    '34': False,
#    '35': False,
#    '37': False,
#    '38': False,
#    '39': False,
#    '40': False},
#   'qe': {'app_upsell': {'g': 'control_only_loggedout_upsell',
#     'p': {'has_new_half_sheet': 'false', 'has_new_app_upsell_sheet': 'false'}},
#    'igl_app_upsell': {'g': '', 'p': {}},
#    'notif': {'g': '', 'p': {}},
#    'log_cont': {'g': 'test_intent_d_42',
#     'p': {'has_contextual_d': 'true', 'has_contextual_m': 'false'}},
#    'onetaplogin': {'g': '', 'p': {}},
#    'onetap': {'g': '', 'p': {}},
#    'multireg_iter': {'g': 'control_11_30', 'p': {'has_back_removed': 'false'}},
#    'felix': {'g': '', 'p': {}},
#    'felix_clear_fb_cookie': {'g': '', 'p': {}},
#    'felix_creation_duration_limits': {'g': '', 'p': {}},
#    'felix_creation_fb_crossposting': {'g': '', 'p': {}},
#    'felix_creation_fb_crossposting_v2': {'g': '', 'p': {}},
#    'felix_creation_validation': {'g': '', 'p': {}},
#    'mweb_topical_explore': {'g': '', 'p': {}},
#    'post_options': {'g': '', 'p': {}},
#    'igtv_public_viewing': {'g': '', 'p': {}},
#    'nux': {'g': '', 'p': {}},
#    'iglscioi': {'g': '', 'p': {}},
#    'wpn': {'g': '', 'p': {}},
#    'wss2': {'g': '', 'p': {}},
#    'sticker_tray': {'g': '', 'p': {}},
#    'web_sentry': {'g': '', 'p': {}},
#    '0': {'p': {'4': True, '7': False, '8': False, '9': False}, 'qex': True},
#    '2': {'p': {'0': True}, 'qex': True},
#    '4': {'p': {'0': True}, 'qex': True},
#    '6': {'p': {'1': True,
#      '5': False,
#      '6': False,
#      '7': False,
#      '9': False,
#      '10': False},
#     'qex': True},
#    '7': {'p': {'0': False}, 'qex': True},
#    '8': {'p': {'0': False, '1': False, '2': False, '3': False, '4': False},
#     'qex': True},
#    '10': {'p': {'2': False}, 'qex': True},
#    '11': {'p': {'0': True}, 'qex': True},
#    '12': {'p': {'0': 5}, 'qex': True},
#    '13': {'p': {'0': True}, 'qex': True},
#    '16': {'p': {'0': False}, 'qex': True},
#    '17': {'p': {'1': True}, 'qex': True},
#    '18': {'p': {'0': True, '1': True}, 'qex': True},
#    '19': {'p': {'0': True}, 'qex': True},
#    '21': {'p': {'0': True, '1': True, '2': False}, 'qex': True},
#    '22': {'p': {'0': False,
#      '1': False,
#      '2': 8.0,
#      '3': 0.85,
#      '4': 0.95,
#      '5': 10.0,
#      '7': False},
#     'qex': True},
#    '23': {'p': {'0': False, '1': False}, 'qex': True},
#    '24': {'p': {'0': True}, 'qex': True},
#    '25': {'p': {}, 'qex': True},
#    '26': {'p': {'0': '...'},
#     'qex': True},
#    '27': {'p': {'0': False}, 'qex': True},
#    '28': {'p': {'0': True}, 'qex': True},
#    '29': {'p': {}, 'qex': True},
#    '30': {'p': {'0': True}, 'qex': True},
#    '31': {'p': {}, 'qex': True}},
#   'probably_has_app': False,
#   'cb': False},
#  'rollout_hash': 'ec3440ce1328',
#  'bundle_variant': 'metro',
#  'is_canary': False}

# %%
import pandas as pd
labeled_data = pd.read_csv('labeled_data.csv')

labeled_data.head()
labeled_data_man = labeled_data[labeled_data['men(1)women(0)company(2)'] == 1.0]
labeled_data_woman = labeled_data[labeled_data['men(1)women(0)company(2)'] == 0.0]
list_man_id = labeled_data_man['id']
list_woman_id = labeled_data_woman['id']

# %%
len(list_woman_id)

# %%
import shutil

for i in ["man", "woman"]:
    if not os.path.isdir("img/{}".format(i)):
        os.mkdir("img/{}".format(i))

for id_i in list_man_id:
    shutil.copyfile("img/{}.png".format(id_i), "img/man/{}.jpg".format(id_i))
    
for id_i in list_woman_id:
    shutil.copyfile("img/{}.png".format(id_i), "img/woman/{}.jpg".format(id_i))

# %%
import pandas as pd
labeled_data = pd.read_csv('labeled_data.csv')

labeled_data.head()
labeled_data_company = labeled_data[labeled_data['men(1)women(0)company(2)'] == 2.0]
labeled_data_ordinary = labeled_data_man + labeled_data_woman
list_company_id = labeled_data_company['id']
list_ordinary_id = labeled_data_ordinary['id']

# %%
len(list_company_id)
len(list_ordinary_id)

# %%
import shutil

for i in ["company", "ordinary"]:
    if not os.path.isdir("img/{}".format(i)):
        os.mkdir("img/{}".format(i))

for id_i in list_company_id:
    shutil.copyfile("img/{}.png".format(id_i), "img/company/{}.jpg".format(id_i))
    
for id_i in list_ordinary_id:
    shutil.copyfile("img/{}.png".format(id_i), "img/ordinary/{}.jpg".format(id_i))

# %%
# -*- coding: utf-8 -*-

import json
import re
import csv
import os
import requests
from typing import Dict
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pprint

f = open("config.json")
config = json.load(f)

#f2= open("user_id.json")
list_user_name = ["ekkkkyu"]

proxies = {
    "http": config["proxy"],
    "https": config["proxy"],
    }

class PlofileCollecter:
    
    def __init__(self):
        self.proxies = proxies
        self.file_pass = "img/{}.png"
        self.plofile_data = {}
        self.instagram_plofile_url = "https://www.instagram.com/{}/"
        self.label = ["id", "url", "icon", "biography", "country", "post_num", "follow", "follower", "hashtag_12post"]
        self.post_num_hashtag = 12

    def download_img(self, url, user_name):
        r = requests.get(url, stream=True)
        if r.status_code == 200:
            save_file_name = self.file_pass.format(user_name)
            with open(save_file_name, 'wb') as f:
                f.write(r.content)

    def get_jsondata_from_username(self, user_name_i):
        url = self.instagram_plofile_url.format(user_name_i)
        self.plofile_data['url'] = url
        response = requests.get(url, proxies=proxies, verify=False)

        soup = BeautifulSoup(response.content, 'html.parser') # 'lxml'  -> 'html.parser' 
        js = soup.find("script", text=re.compile("window._sharedData")).text
        json_data = json.loads(js[js.find("{"):js.rfind("}")+1]);
        pprint.pprint(json_data)
        return json_data
    
    def get_plofile_data_from_jsondata(self, json_data):
        user_data = json_data['entry_data']['ProfilePage'][0]['graphql']['user']
        timeline_media = user_data['edge_owner_to_timeline_media'][ 'edges']
        self.plofile_data['icon_src'] = user_data['profile_pic_url']
        self.plofile_data['biography'] = user_data['biography']        
        self.plofile_data['country'] = json_data['country_code']
        self.plofile_data['post'] = user_data['edge_owner_to_timeline_media']['count']
        self.plofile_data['follow'] = user_data['edge_follow']['count']
        self.plofile_data['follower'] = user_data['edge_followed_by']['count']
        
        hashtag = []
        for i in range(min(self.post_num_hashtag, int(self.plofile_data['post']))):
            try:
                text = timeline_media[i]['node']['edge_media_to_caption']['edges'][0]['node']['text']
                hashtag.append(self.text2hashtag(text))
            except:
                pass
        self.plofile_data['hashtag'] = self.flatten(hashtag)
        
    def text2hashtag(self, text):
        pattern = "\#[^(\ ¥\#¥\n)]*"
        return re.findall(pattern, text)
    
    def flatten(self, nested_list):
        """2重のリストをフラットにする関数"""
        return [e for inner_list in nested_list for e in inner_list]
        
    def save_idlist2json_file(self, data):
        file_name = "data.json"
        fw = open(file_name,'w')
        json.dump(data, fw, indent=4)
        
    def write2csv(self, row_data):
        if os.path.exists('data.csv'):
            with open('data.csv', 'a') as f_csv:
                writer = csv.writer(f_csv)
                writer.writerow(row_data)
        else:
            with open('data.csv', 'w') as f_csv:
                writer = csv.writer(f_csv)
                writer.writerow(self.label)
                writer.writerow(row_data)

    def main_loop(self, list_user_name):
        for user_num_i, user_name_i in enumerate(list_user_name):
            try:
                self.plofile_data['username'] = user_name_i
                json_data = self.get_jsondata_from_username(user_name_i)
                self.get_plofile_data_from_jsondata(json_data)
                #self.download_img(self.plofile_data['icon_src'], user_name_i)   
                print("---------{}/{}---------".format(user_num_i + 1, len(list_user_name)))
                #print(self.plofile_data.values())
                #self.write2csv(self.plofile_data.values())
            except:
                pass
            
if __name__ == '__main__':
    pc = PlofileCollecter()
    pc.main_loop(list_user_name)
